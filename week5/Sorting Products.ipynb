# %% [markdown]
# # Sorting Products
# - Sıralama konusu sadece ürün sıralamada karşımıza çıkmaz. Örneğin bir cv'de kişinin mezuniyet puanı, çalışma süresi, mülakat puanı gibi puanların değerlendirilmesinde kullanılabilir.
# - İlgili puanlara belirli bir ağırlık verilerek değerlendirme yapılabilir. Örneğin mülakt puanı 55% yabancı dil %25 ve mezuniyet puanına 20% ağırlık verilebilir. Ve çıkan sonuç sıralanarak adaylar seçilebilir.
# - Kişi arama kısmına bir şey yazdığında yazılan sonuç ile en alakalı sonuçlar getirilebilir. Arama metnine en benzer ürünler getirilir.

# %% [markdown]
# ## Derecelendirmeye Göre Sıralama (Sorting by Rating)

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import scipy.stats as st
import math

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.float_format", lambda x: "%.5f" % x)

# %%
df = pd.read_csv("C:/measurement_problems/datasets/product_sorting.csv")
df.head(10)
# Out:
#                                          course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point
# 0  (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6
# 1  Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45
# 2           5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24
# 3    R ile Veri Bilimi ve Machine Learning (35 Saat)  Veri Bilimi Okulu            6626 4.60000            1027      688      257       51       10       21
# 4  (2020) Python ile Makine Öğrenmesi (Machine Le...  Veri Bilimi Okulu           11314 4.60000             969      717      194       38       10       10
# ...

# %%
df.shape
# Out:
# (32, 10)

# %% [markdown]
# ## Sorting by Rating

# %%
df.sort_values("rating", ascending=False).head(15)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6
# 10        İleri Düzey Excel|Dashboard|Excel İp Uçları  Veri Bilimi Okulu            9554 4.80000            2266     1654      499       91       22        0
# 19                     Alıştırmalarla SQL Öğreniyorum  Veri Bilimi Okulu            3155 4.80000             235      200       31        4        0        0
# 5                                            Course_1       Instructor_2            4601 4.80000             213      164       45        4        0        0
# 6                                            Course_2       Instructor_3            3171 4.70000             856      582      205       51        9        9
# ...

# %% [markdown]
# - Rating'e göre sıralama yapıldığı zaman 2 faktör gözden kaçmış oluyor. Satın alma sayıları ve yorum sayıları. Bu değişkenleri de sıralama yaparken göz önünde bulundurmak gerekir.

# %% [markdown]
# ## Sorting by Comment Count | Purchase Count

# %%
df.sort_values("purchase_count", ascending=False).head(15)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point
# 1   Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45
# 11                                           Course_3       Instructor_4           24809 4.30000             250       95       87       51       12        5
# 2            5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6
# 20                                           Course_9       Instructor_3           12946 4.50000            3371     2191      877      203       33       67
# ...

# %%
df.sort_values("commment_count", ascending=False).head(15)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6
# 1   Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45
# 20                                           Course_9       Instructor_3           12946 4.50000            3371     2191      877      203       33       67
# 14                       Uçtan Uca SQL Server Eğitimi  Veri Bilimi Okulu           12893 4.70000            2425     1722      510      145       24       24
# 2            5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24
# ...

# %% [markdown]
# - Her iki metrikte sıralama için yeterli değil. Yorum sayısı diğerlerine göre biraz daha iyi sonuç veriyor.
# - 3 metriği göz önünde bulundurarak bir sıralama yapmak en sağlıklısı olacaktır. Bunun için 3 metriği standartlaştırıp,tek bir metrik haline getirilebilir.

# %% [markdown]
# ## Sorting by Rating, Comment, Purchase

# %%
scaler = MinMaxScaler(feature_range=(1, 5))
df["purchase_count_scaled"] = scaler.fit_transform(df[["purchase_count"]])
df.head()
# Out:
#                                          course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled
# 0  (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801
# 1  Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000
# 2           5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24                2.54684
# 3    R ile Veri Bilimi ve Machine Learning (35 Saat)  Veri Bilimi Okulu            6626 4.60000            1027      688      257       51       10       21                1.54669
# ...

# %%
df["comment_count_scaled"] = scaler.fit_transform(df[["commment_count"]])
df.head()
# İlgili değişkenler aynı skalaya indirgendi
# Out:
#                                          course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled
# 0  (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000
# 1  Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470
# 2           5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24                2.54684               3.04161
# ...

# %%
df["comment_count_scaled"] * 32 / 100 + df["purchase_count_scaled"] * 26 / 100 + df["rating"] * 42 / 100
# Out:
# 0    4.24988
# 1    4.79510
# 2    3.48349
# 3    2.93711
# 4    3.02204
# 5    2.75165
# 6    2.85721
# 7    2.52239
# 8    2.75990
# 9    2.81623
# 10   3.42792
# 11   2.98739
# 12   2.52869
# 13   2.72186
# 14   3.50198
# 15   3.36577
# 16   2.51798
# 17   2.28232
# 18   2.45807
# 19   2.72659
# 20   3.68156
# 21   2.51906
# 22   2.53828
# 23   2.35459
# 24   2.26479
# 25   2.02105
# 26   2.43612
# 27   2.56168
# 28   2.54467
# 29   1.92584
# 30   1.92400
# 31   2.27376
# dtype: float64

# %%
def weighted_sorting_score(dataframe, w1=32, w2=26, w3=42):
    return (df["comment_count_scaled"] * w1 / 100 +
            df["purchase_count_scaled"] * w2 / 100 + 
            df["rating"] * w3 / 100)

df["weighted_sorting_score"] = weighted_sorting_score(df)

# %%
df.sort_values("weighted_sorting_score", ascending=False).head(20)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score
# 1   Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470                 4.79510
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000                 4.24988
# 20                                           Course_9       Instructor_3           12946 4.50000            3371     2191      877      203       33       67                2.07051               3.91634                 3.68156
# ...

# %% [markdown]
# ## Bayesian Average Rating Score

# %%
# Sorting Products with 5 Star Rated
# Sorting Products According to Distribution of 5 Star Rating

# Puan dağılımları üzerinden olasılıklsal ortalama hesaplar
def bayesian_average_rating(n, confidence=0.95):
    if sum(n) == 0:
        return 0
    K = len(n)
    z = st.norm.ppf(1 - (1 - confidence) / 2)
    N = sum(n)
    first_part = 0.0
    second_part = 0.0
    for k, n_k in enumerate(n):
        first_part += (k + 1) * (n[k] + 1) / (N + K)
        second_part += (k + 1) * (k + 1) * (n[k] + 1) / (N + K)
    score = first_part - z * math.sqrt((second_part - first_part * first_part) / (N + K + 1))
    return score


df.head()
# Out:
#                                          course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score
# 0  (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000                 4.24988
# 1  Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470                 4.79510
# 2           5 Saatte Veri Bilimci Olun (Valla Billa)       Instructor_1           18693 4.40000            2362     1582      567      165       24       24                2.54684               3.04161                 3.48349
# ...

# %%
df["bar_score"] = df.apply(lambda x: bayesian_average_rating(x[["1_point",
                                                                "2_point",
                                                                "3_point",
                                                                "4_point",
                                                                "5_point"]]), axis=1)

df.sort_values("weighted_sorting_score", ascending=False).head(20)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score  bar_score
# 1   Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470                 4.79510    4.51604
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000                 4.24988    4.66586
# 20                                           Course_9       Instructor_3           12946 4.50000            3371     2191      877      203       33       67                2.07051               3.91634                 3.68156    4.48063
# ...

# %%
# oluşan skorlar rating yerine kullanılabilir
df.sort_values("bar_score", ascending=False).head(20)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score  bar_score
# 19                     Alıştırmalarla SQL Öğreniyorum  Veri Bilimi Okulu            3155 4.80000             235      200       31        4        0        0                1.25901               1.19766                 2.72659    4.72913
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000                 4.24988    4.66586
# 10        İleri Düzey Excel|Dashboard|Excel İp Uçları  Veri Bilimi Okulu            9554 4.80000            2266     1654      499       91       22        0                1.78937               2.95839                 3.42792    4.64168
# ...

# %%
df[df["course_name"].index.isin([5, 1])].sort_values("bar_score", ascending=False)
# Out:
#                                          course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score  bar_score
# 5                                           Course_1       Instructor_2            4601 4.80000             213      164       45        4        0        0                1.37886               1.17859                 2.75165    4.63448
# 1  Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470                 4.79510    4.51604

# %% [markdown]
# ## Hybrid Sorting: BAR Score + Diğer Faktorler

# %%
def hybrid_sorting_score(dataframe, bar_w=60, wss_w=40):
    bar_score = dataframe.apply(lambda x: bayesian_average_rating(x[["1_point",
                                                                     "2_point",
                                                                     "3_point",
                                                                     "4_point",
                                                                     "5_point"]]), axis=1)
    wss_score = weighted_sorting_score(dataframe)

    return bar_score*bar_w/100 + wss_score*wss_w/100


df["hybrid_sorting_score"] = hybrid_sorting_score(df)

df.sort_values("hybrid_sorting_score", ascending=False).head(20)
# Out:
#                                           course_name    instructor_name  purchase_count  rating  commment_count  5_point  4_point  3_point  2_point  1_point  purchase_count_scaled  comment_count_scaled  weighted_sorting_score  bar_score  hybrid_sorting_score
# 1   Python: Yapay Zeka ve Veri Bilimi için Python ...  Veri Bilimi Okulu           48291 4.60000            4488     2962     1122      314       45       45                5.00000               4.88470                 4.79510    4.51604               4.62766
# 0   (50+ Saat) Python A-Z™: Veri Bilimi ve Machine...  Veri Bilimi Okulu           17380 4.80000            4621     3466      924      185       46        6                2.43801               5.00000                 4.24988    4.66586               4.49947
# ...
